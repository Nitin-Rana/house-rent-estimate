# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("houses_to_rent_combined.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16216 entries, 0 to 16215
# Data columns (total 12 columns):
# city              16216 non-null object
# area              16216 non-null int64
# rooms             16216 non-null int64
# bathroom          16216 non-null int64
# parking spaces    16216 non-null int64
# floor             16216 non-null int64
# animal            16216 non-null object
# furniture         16216 non-null object
# Hassoc_tax        16216 non-null object
# rent              16216 non-null int64
# prop_tax          16216 non-null object
# fire_insur        16216 non-null int64
# dtypes: int64(7), object(5)
# memory usage: 1.5+ MB

# %%
df.head(10)
# Out:
#   city  area  rooms  bathroom  parking spaces  floor     animal  \
# 0    1   240      3         3               4      0      acept
# 1    0    64      2         1               1     10      acept
# 2    1   443      5         5               4      3      acept
# 3    1    73      2         2               1     12      acept
# 4    1    19      1         1               0      0  not acept
# 5    1    13      1         1               0      2      acept
# 6    1    55      1         1               1      2      acept
# 7    1    55      2         2               1      2      acept
# 8    1    82      3         1               1      3      acept
# 9    1    32      1         1               1     16      acept
#
#        furniture Hassoc_tax  rent prop_tax  fire_insur
# 0      furnished          0  8000     1000         121
# 1  not furnished        540   820      122          11
# 2      furnished       4172  7000     1417          89
# ...

# %%
df[(df['Hassoc_tax'] == 'Sem info') | (df['Hassoc_tax'] == 'Incluso')]
# Out:
#      city  area  rooms  bathroom  parking spaces  floor     animal  \
# 35      1   250      4         4               2      0  not acept
# 38      1   180      3         4               5      0      acept
# 60      1    20      1         1               0      1  not acept
# 137     1    90      2         1               1      0      acept
# 156     1   340      4         6               6      0      acept
# 162     1   500      4         4               3      0      acept
# 171     1    20      1         1               0      1      acept
# 213     1   400      4         4               3      0      acept
# 225     1   122      3         4               3      5      acept
# 238     1   200      3         3               0      0      acept
# 277     1   180      3         2               1      0      acept
# 296     1    38      1         1               0      0  not acept
# 345     1    90      1         1               0      0  not acept
# ...

# %%
df[df['prop_tax'] == 'Incluso']
# Out:
#      city  area  rooms  bathroom  parking spaces  floor     animal  \
# 408     1    30      1         1               1     11      acept
# 983     1    65      2         1               1      4      acept
# 1337    1    45      1         1               1      9      acept
# 1621    1    27      1         1               1      6  not acept
# 1698    1   130      3         1               1      0      acept
# 1873    1    48      1         1               1      2      acept
# 2007    1    45      1         1               1      2      acept
# 2685    1    45      1         1               1     11  not acept
# 2762    1    32      1         1               0     13      acept
# 2956    1    60      2         1               1      1      acept
# 3061    1   102      3         3               2      9      acept
# 3557    1   213      3         5               5     10      acept
# 3633    1    50      2         1               1      1  not acept
# ...

# %%
df.loc[df['Hassoc_tax'] == 'Incluso','Hassoc_tax'] = 0
df.loc[df['prop_tax'] == 'Incluso','prop_tax'] = 0

# %%
df[(df['Hassoc_tax'] == 'Sem info') | (df['Hassoc_tax'] == 'Incluso')]
# Out:
#      city  area  rooms  bathroom  parking spaces  floor     animal  \
# 35      1   250      4         4               2      0  not acept
# 38      1   180      3         4               5      0      acept
# 156     1   340      4         6               6      0      acept
# 162     1   500      4         4               3      0      acept
# 213     1   400      4         4               3      0      acept
# 238     1   200      3         3               0      0      acept
# 277     1   180      3         2               1      0      acept
# 296     1    38      1         1               0      0  not acept
# 345     1    90      1         1               0      0  not acept
# 351     1    30      1         1               0      1  not acept
# 383     1   270      3         4               3      0      acept
# 428     1   350      5         4               8      0  not acept
# 429     1    78      2         1               1      0      acept
# ...

# %%
df[df['prop_tax'] == 'Incluso']
# Out:
# Empty DataFrame
# Columns: [city, area, rooms, bathroom, parking spaces, floor, animal, furniture, Hassoc_tax, rent, prop_tax, fire_insur]
# Index: []

# %%
invalid_Hassoc_tax_index = df[df['Hassoc_tax'] == 'Sem info'].index
df.drop(invalid_Hassoc_tax_index,inplace=True)

# %%
df[df['Hassoc_tax'] == 'Sem info']
# Out:
# Empty DataFrame
# Columns: [city, area, rooms, bathroom, parking spaces, floor, animal, furniture, Hassoc_tax, rent, prop_tax, fire_insur]
# Index: []

# %%
df['Hassoc_tax'] = df['Hassoc_tax'].astype("int64")
df['prop_tax'] = df['prop_tax'].astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16102 entries, 0 to 16215
# Data columns (total 12 columns):
# city              16102 non-null object
# area              16102 non-null int64
# rooms             16102 non-null int64
# bathroom          16102 non-null int64
# parking spaces    16102 non-null int64
# floor             16102 non-null int64
# animal            16102 non-null object
# furniture         16102 non-null object
# Hassoc_tax        16102 non-null int64
# rent              16102 non-null int64
# prop_tax          16102 non-null int64
# fire_insur        16102 non-null int64
# dtypes: int64(9), object(3)
# memory usage: 1.6+ MB

# %%
df['city'].unique()
# Out:
# array(['1', '0', 'São Paulo', 'Porto Alegre', 'Rio de Janeiro',
#        'Campinas', 'Belo Horizonte'], dtype=object)

# %%
df.loc[df['city'] == '0','city'] = 'city0'
df.loc[df['city'] == '1','city'] = 'city1'

# %%
df['city'].unique()
# Out:
# array(['city1', 'city0', 'São Paulo', 'Porto Alegre', 'Rio de Janeiro',
#        'Campinas', 'Belo Horizonte'], dtype=object)

# %%
df.head(10)
# Out:
#     city  area  rooms  bathroom  parking spaces  floor     animal  \
# 0  city1   240      3         3               4      0      acept
# 1  city0    64      2         1               1     10      acept
# 2  city1   443      5         5               4      3      acept
# 3  city1    73      2         2               1     12      acept
# 4  city1    19      1         1               0      0  not acept
# 5  city1    13      1         1               0      2      acept
# 6  city1    55      1         1               1      2      acept
# 7  city1    55      2         2               1      2      acept
# 8  city1    82      3         1               1      3      acept
# 9  city1    32      1         1               1     16      acept
#
#        furniture  Hassoc_tax  rent  prop_tax  fire_insur
# 0      furnished           0  8000      1000         121
# 1  not furnished         540   820       122          11
# 2      furnished        4172  7000      1417          89
# ...

# %% [markdown]
# Removing Outliers from Rent and Area

# %%
sns.boxplot(data = df['rent'])

# %%
sns.boxplot(data = df['area'])

# %%
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

# %%
df1 = df.copy()

# %%
df2 = remove_outlier(remove_outlier(df1, 'rent'), 'area')

# %%
df2.shape
# Out:
# (14196, 12)

# %%
# Lets take a look on how our data was distributed before and after treat outliers

plt.figure(1, figsize=(20, 10))
plt.subplot(2, 2, 1)
sns.distplot(df1['rent'])
plt.title('Before Removing Outliers')
plt.subplot(2, 2, 2)
sns.distplot(df2['rent'])
plt.title('After Removing Outliers')
# Out:
# Text(0.5, 1.0, 'After Removing Outliers')

# %%
# Lets take a look on how our data was distributed before and after treat outliers

plt.figure(1, figsize=(20, 10))
plt.subplot(2, 2, 1)
sns.distplot(df1['area'])
plt.title('Before Removing Outliers')
plt.subplot(2, 2, 2)
sns.distplot(df2['area'])
plt.title('After Removing Outliers')
# Out:
# Text(0.5, 1.0, 'After Removing Outliers')

# %%
sns.boxplot(data = df2['rent'])

# %%
sns.boxplot(data = df2['area'])

# %%
df2.to_csv("houses_to_rent_comb_cleaned.csv",index = False)
